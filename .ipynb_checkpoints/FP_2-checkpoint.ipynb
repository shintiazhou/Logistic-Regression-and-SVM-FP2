# %%
# import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm


from sklearn.datasets import load_digits
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing

# %matplotlib inline

# %%
df = pd.read_csv('dataset/weatherAUS.csv')
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
df.shape
# Out:
# (145460, 23)

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
numerical_df = df.select_dtypes(include=['number'])

numerical_df
# Out:
#         MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0          13.4     22.9       0.6          NaN       NaN           44.0
# 1           7.4     25.1       0.0          NaN       NaN           44.0
# 2          12.9     25.7       0.0          NaN       NaN           46.0
# 3           9.2     28.0       0.0          NaN       NaN           24.0
# 4          17.5     32.3       1.0          NaN       NaN           41.0
# ...         ...      ...       ...          ...       ...            ...
# 145455      2.8     23.4       0.0          NaN       NaN           31.0
# 145456      3.6     25.3       0.0          NaN       NaN           22.0
# 145457      5.4     26.9       0.0          NaN       NaN           37.0
# 145458      7.8     27.0       0.0          NaN       NaN           28.0
# 145459     14.9      NaN       0.0          NaN       NaN            NaN
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# ...

# %%
def plot_corr(df, size=15):
    corr = df.corr()
    plt.figure(figsize=(size, size))
    plt.matshow(corr)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical')
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.show()

# %%
plot_corr(numerical_df)

# %%
numerical_df.corr()
# Out:
#                 MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# MinTemp        1.000000  0.736555  0.103938     0.466993  0.072586
# MaxTemp        0.736555  1.000000 -0.074992     0.587932  0.470156
# Rainfall       0.103938 -0.074992  1.000000    -0.064351 -0.227549
# Evaporation    0.466993  0.587932 -0.064351     1.000000  0.365602
# Sunshine       0.072586  0.470156 -0.227549     0.365602  1.000000
# WindGustSpeed  0.177415  0.067615  0.133659     0.203021 -0.034750
# WindSpeed9am   0.175064  0.014450  0.087338     0.193084  0.005499
# WindSpeed3pm   0.175173  0.050300  0.057887     0.129400  0.053834
# Humidity9am   -0.232899 -0.504110  0.224405    -0.504092 -0.490819
# Humidity3pm    0.006089 -0.508855  0.255755    -0.390243 -0.629130
# Pressure9am   -0.450970 -0.332061 -0.168154    -0.270362  0.041970
# Pressure3pm   -0.461292 -0.427167 -0.126534    -0.293581 -0.019719
# Cloud9am       0.078754 -0.289370  0.198528    -0.183793 -0.675323
# ...

# %% [markdown]
# pada kolom Temp9pm, Temp3pm, Pressure3pm, terdapat kolerasi maka akan di drop

# %%
del df['Temp3pm']
del df['Temp9am']
del df['Pressure3pm']

# %%
numerical_df = df.select_dtypes(include=['number'])
plot_corr(numerical_df)

# %%
 df['Location'].unique()
# Out:
# array(['Albury', 'BadgerysCreek', 'Cobar', 'CoffsHarbour', 'Moree',
#        'Newcastle', 'NorahHead', 'NorfolkIsland', 'Penrith', 'Richmond',
#        'Sydney', 'SydneyAirport', 'WaggaWagga', 'Williamtown',
#        'Wollongong', 'Canberra', 'Tuggeranong', 'MountGinini', 'Ballarat',
#        'Bendigo', 'Sale', 'MelbourneAirport', 'Melbourne', 'Mildura',
#        'Nhil', 'Portland', 'Watsonia', 'Dartmoor', 'Brisbane', 'Cairns',
#        'GoldCoast', 'Townsville', 'Adelaide', 'MountGambier', 'Nuriootpa',
#        'Woomera', 'Albany', 'Witchcliffe', 'PearceRAAF', 'PerthAirport',
#        'Perth', 'SalmonGums', 'Walpole', 'Hobart', 'Launceston',
#        'AliceSprings', 'Darwin', 'Katherine', 'Uluru'], dtype=object)

# %%
Canberra_df = df.loc[df['Location']=='Canberra'].copy()
Canberra_df.shape
# Out:
# (3436, 20)

# %% [markdown]
# # Convert categorial and binary features to float

# %%
le = preprocessing.LabelEncoder()

binary = ['RainToday', 'RainTomorrow']
categorical = ['WindGustDir', 'WindDir9am','WindDir3pm']
numerical =  df.select_dtypes(include=['number']).columns
result = {'Yes': 1, 'No': 0}

Canberra_df.dropna(subset=binary, inplace=True)

for column in binary:
    Canberra_df.loc[:, column] = Canberra_df[column].replace(result)
    
for col in categorical:
    mode_value = Canberra_df[col].mode()[0]
    Canberra_df[col].fillna(mode_value, inplace=True)
    Canberra_df[col] = le.fit_transform(Canberra_df[col]).astype(float)

Canberra_df[binary] = Canberra_df[binary].astype(float)
Canberra_df.head()
# Out:
#              Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 45587  2007-11-01  Canberra      8.0     24.3       0.0          3.4
# 45588  2007-11-02  Canberra     14.0     26.9       3.6          4.4
# 45589  2007-11-03  Canberra     13.7     23.4       3.6          5.8
# 45590  2007-11-04  Canberra     13.3     15.5      39.8          7.2
# 45591  2007-11-05  Canberra      7.6     16.1       2.8          5.6
#
#        Sunshine  WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  \
# 45587       6.3          7.0           30.0        12.0         7.0
# 45588       9.7          1.0           39.0         0.0        13.0
# 45589       3.3          7.0           85.0         3.0         5.0
# 45590       9.1          7.0           54.0        14.0        13.0
# 45591      10.6         10.0           50.0        10.0         2.0
#
#        WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# ...

# %%
num_obs = len(Canberra_df)

num_true = len(Canberra_df[Canberra_df['RainTomorrow'] == 1])  # Calculate the number of True occurrences
num_false = len(Canberra_df[Canberra_df['RainTomorrow'] == 0])  # Calculate the number of False occurrences

print('Prediction of rain tomorrow (True): {0} ({1:2.2f}%)'.format(num_true, (num_true / num_obs) * 100))
print('Prediction of no rain tomorrow (False): {0} ({1:2.2f}%)'.format(num_false, (num_false / num_obs) * 100))
# Out:
# Prediction of rain tomorrow (True): 625 (18.37%)
# Prediction of no rain tomorrow (False): 2777 (81.63%)

# %% [markdown]
# # Replace NaN with mean for numerical features

# %%
Canberra_df[numerical] = Canberra_df[numerical].fillna(Canberra_df[numerical].mean())

# %% [markdown]
# # Logistic Regression Execution

# %%
scaler = StandardScaler()
y = Canberra_df['RainTomorrow']
x =  Canberra_df.drop(columns=['RainTomorrow','Date','Location'],axis=1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,train_size=0.7,random_state=42)
x_train = scaler.fit_transform(x_train)

# %%
model = LogisticRegression(solver='liblinear',C=0.7,multi_class='ovr',random_state=42,max_iter=10000)
model.fit(x_train, y_train)
# Out:
# LogisticRegression(C=0.7, max_iter=10000, multi_class='ovr', random_state=42,
#                    solver='liblinear')

# %%
x_test = scaler.transform(x_test)

# %%
y_pred = model.predict(x_test)

# %%
print("Accuracy:",model.score(x_train,y_train))
print("Accuracy:",model.score(x_test,y_test))
# Out:
# Accuracy: 0.8605627887442251
# Accuracy: 0.8863858961802155

# %%
cm_df = pd.DataFrame(confusion_matrix(y_test,y_pred))
cm_df.columns = ['Predicted 0','Predicted 1']
cm_df = cm_df.rename(index={0:"Actual 0",1:"Actual 1"})
cm_df
# Out:
#           Predicted 0  Predicted 1
# Actual 0          822           27
# Actual 1           89           83

# %% [markdown]
# # SVM

# %%
from sklearn import svm
from sklearn import metrics

clf= svm.SVC(kernel='linear')

clf.fit(x_train,y_train)

y_pred=clf.predict(x_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy: 0.8863858961802155
